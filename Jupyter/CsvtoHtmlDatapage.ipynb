# %%
import pandas as pd

# %%
df = pd.read_csv("../Resources/landfall.csv")

# %%
df.head()
# Out:
#          ID     Name  Year  Month  Day Status  Wind_mph  Latitude Longitude
# 0  AL011851  UNNAMED  1851      6   25     HU        80      28.2     -96.8
# 1  AL041851  UNNAMED  1851      8   23     HU       100      30.1     -85.7
# 2  AL061851  UNNAMED  1851     10   19     TS        50      41.1     -71.7
# 3  AL011852  UNNAMED  1852      8   26     HU       100      30.2     -88.6
# 4  AL031852  UNNAMED  1852      9   12     HU        70      28.0     -82.8

# %%
df.to_html("hurricane.htm")
html_file = df.to_html()

# %%
print(html_file)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Name</th>
#       <th>Year</th>
#       <th>Month</th>
#       <th>Day</th>
#       <th>Status</th>
#       <th>Wind_mph</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AL011851</td>
#       <td>UNNAMED</td>
#       <td>1851</td>
#       <td>6</td>
#       <td>25</td>
#       <td>HU</td>
#       <td>80</td>
#       <td>28.2</td>
#       <td>-96.8</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AL041851</td>
#       <td>UNNAMED</td>
#       <td>1851</td>
#       <td>8</td>
#       <td>23</td>
#       <td>HU</td>
#       <td>100</td>
#       <td>30.1</td>
#       <td>-85.7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AL061851</td>
#       <td>UNNAMED</td>
#       <td>1851</td>
#       <td>10</td>
#       <td>19</td>
#       <td>TS</td>
# ...
